# %% [markdown]
# ## La librería os: Llamadas al sistema operativo
#
#
# El módulo __`os`__ da acceso a llamadas del sistema operativo sobre el que se
# está ejecutando el intérprete de Python.

# %% [markdown]
# A nivel de diseño, las llamadas
# que funcionana en todos los sistemas usan y devuelven la misma interfaz,
# independiente del S.O. Por ejemplo, la función stat siempre devuelve
# información sobre un fichero con el mismo formato, independientemente de
# la plataforma aunque, obviamente, las llamadas realizadas al sistema
# operativo sean diferentes.

# %% [markdown]
# Las funciones que solo están disponibles para un determinado sistema
# operativo estan en submódulos aparte.

# %% [markdown]
# El submodulo `os.path` (cargado automáticamente) incluye funciones de
# ayuda para trabajar con rutas de archivos.

# %% [markdown]
# Algunas de las funciones y atributos de este módulo son:

# %% [markdown]
# -   `os.name` : El nombre del sistema operativo sobre el que se está
#     ejecutando Python. Algunos valores posibles son posix, nt y java. Si
#     se desea más información de este tipo, véase también `sys.platform`
#     y `os.uname`

# %% [markdown]
# Ejercicio: Importar `os` y imprimimos `os.name`

# %%
import os
print(os.name)
# Out:
# posix

# %% [markdown]
# -   `os.environ` : Un diccionario que contiene las variables de entorno
#     definidas en el sistema operativo. Los valores se obtiene la primera
#     vez que se importa el módulo, por lo que no reflejaran los cambios
#     hechos después.

# %%
import os

for name in os.environ:
    print(name)
# Out:
# SHELL
# SESSION_MANAGER
# QT_ACCESSIBILITY
# COLORTERM
# XDG_CONFIG_DIRS
# XDG_SESSION_PATH
# GNOME_DESKTOP_SESSION_ID
# LANGUAGE
# MANDATORY_PATH
# LC_ADDRESS
# LC_NAME
# SSH_AUTH_SOCK
# DESKTOP_SESSION
# LC_MONETARY
# SSH_AGENT_PID
# GTK_MODULES
# XDG_SEAT
# ZEITGEIST_DATA_PATH
# PWD
# LOGNAME
# XDG_SESSION_DESKTOP
# QT_QPA_PLATFORMTHEME
# XDG_SESSION_TYPE
# GPG_AGENT_INFO
# XAUTHORITY
# XDG_GREETER_DATA_DIR
# GDM_LANG
# VIRTUALENVWRAPPER_SCRIPT
# HOME
# IM_CONFIG_PHASE
# LC_PAPER
# LANG
# LS_COLORS
# XDG_CURRENT_DESKTOP
# VIRTUAL_ENV
# VTE_VERSION
# VIRTUALENVWRAPPER_WORKON_CD
# G_ENABLE_DIAGNOSTIC
# XDG_SEAT_PATH
# GNOME_TERMINAL_SCREEN
# VIRTUALENVWRAPPER_PYTHON
# INVOCATION_ID
# MANAGERPID
# WORKON_HOME
# LESSCLOSE
# XDG_SESSION_CLASS
# TERM
# LC_IDENTIFICATION
# GTK_OVERLAY_SCROLLING
# DEFAULTS_PATH
# LESSOPEN
# USER
# GNOME_TERMINAL_SERVICE
# VIRTUALENVWRAPPER_PROJECT_FILENAME
# DISPLAY
# SHLVL
# LC_TELEPHONE
# LC_MEASUREMENT
# XDG_VTNR
# XDG_SESSION_ID
# XDG_RUNTIME_DIR
# PS1
# JOURNAL_STREAM
# XDG_DATA_DIRS
# PATH
# VIRTUALENVWRAPPER_HOOK_DIR
# GDMSESSION
# DBUS_SESSION_BUS_ADDRESS
# LC_NUMERIC
# OLDPWD
# _
# KERNEL_LAUNCH_TIMEOUT
# JPY_PARENT_PID
# CLICOLOR
# PAGER
# GIT_PAGER
# MPLBACKEND

# %%
print(os.environ['HOME'])
# Out:
# /home/jileon

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'os.ipynb', 'os.rst', 'os.md']

# %% [markdown]
# -   `os.path.getsize(path)` : Devuelve el tamaño, en bytes, del fichero
#     cuya ruta se la pasa como parámetro.

# %%
import os
# hola

print(os.path.getsize("os.ipynb"))
# Out:
# 21825

# %%
for n in os.listdir():
    print(f"El fichero {n} ocupa {os.path.getsize(n)//1024} Kb")
# Out:
# El fichero .ipynb_checkpoints ocupa 4 Kb
# El fichero os.ipynb ocupa 21 Kb
# El fichero os.rst ocupa 3 Kb
# El fichero os.md ocupa 3 Kb

# %% [markdown]
# -   `os.path.getmtime(path)` : Devuelve el tiempo de la ultima
#  modificación del archivo. El valor es en tiempo unix: el número de
#  segundos desde la medianoche UTC del 1 de enero de 1970. Vease el
#  módulo [`time`](time.ipynb).

# %%
import datetime

for n in os.listdir():
    ts = os.path.getmtime(n)
    dt = datetime.datetime.fromtimestamp(ts)
    print(f"El fichero {n} se modificó en {dt}")
# Out:
# El fichero .ipynb_checkpoints se modificó en 2020-10-19 15:25:56.266829
# El fichero os.ipynb se modificó en 2020-10-19 16:58:56.159873
# El fichero os.rst se modificó en 2020-03-04 22:23:13.635833
# El fichero os.md se modificó en 2020-04-14 15:41:20.198430

# %%
import os

print(os.path.getmtime("os.ipynb"))
# Out:
# 1586901091.0901787

# %% [markdown]
# -  `os.path.listdir(path)` : Devuelve una lista con los nombres de las
# entradas en el directorio indicado por el parámetro `path`. Si no se
# especifica el parámetro se listará el directorio actual. La lista no
# viene en ningún orden determinado, y no incluye las entradas especiales
# `.` (Directorio actual) ni `..` (Padre del directorio actual).

# %%
os.listdir()
# Out:
# ['time.rst',
#  'hashlib.rst',
#  'argparse.ipynb',
#  'traceback.ipynb',
#  'lorem.txt.gz',
#  'curses',
#  'timeit.ipynb',
#  '.DS_Store',
#  'datetime.rst',
#  'smtplib.rst',
#  'sys.rst',
#  'urllib.rst',
#  'sys.ipynb',
#  'file.txt.gz',
#  'xml.rst',
#  'pdb.ipynb',
#  'compression.ipynb',
#  'heapq.rst',
#  'curses.rst',
#  're.rst',
#  'traceback.rst',
#  'os.ipynb',
#  'base64.ipynb',
#  'sqlite3.rst',
#  'img',
#  'zipfile.ipynb',
#  'itertools.rst',
#  'argparse.rst',
#  'zlib_sol_01.py',
#  'zlib.ipynb',
#  'http_server.rst',
#  'timeit.rst',
#  'random.rst',
#  'lorem.txt',
#  'files.backup',
#  '.ipynb_checkpoints',
#  'difflib.rst',
#  'csv.rst',
#  'logging.rst',
#  'base64.rst',
#  'pdb.rst',
#  'logging.ipynb',
#  'os.rst',
#  'itertools.ipynb',
#  'gzip.ipynb',
#  'collections.rst']

# %%
# !touch timeit.rst
for filename in os.listdir(): 
    tiempo_mod = os.path.getmtime(filename) 
    print(filename, tiempo_mod)
# Out:
# time.rst 1586806837.0959044
# hashlib.rst 1586807932.02431
# argparse.ipynb 1586803719.5171173
# traceback.ipynb 1586802915.274425
# lorem.txt.gz 1586733063.4949968
# curses 1583745150.370969
# timeit.ipynb 1586801625.1886237
# .DS_Store 1584451638.9042914
# datetime.rst 1586813693.5210686
# smtplib.rst 1586807747.020284
# sys.rst 1586863021.0782957
# urllib.rst 1586807570.760519
# sys.ipynb 1586900256.8099008
# file.txt.gz 1586730612.0464232
# xml.rst 1586806955.8499613
# pdb.ipynb 1586806220.3642125
# compression.ipynb 1586734180.1917906
# heapq.rst 1583176433.088301
# curses.rst 1583745946.1560829
# re.rst 1583176325.3345604
# traceback.rst 1586802118.9939473
# os.ipynb 1586901211.1460376
# base64.ipynb 1586728118.4503722
# sqlite3.rst 1583431666.7162724
# img 1586804999.1669888
# zipfile.ipynb 1586738307.0160286
# itertools.rst 1586787417.5973184
# argparse.rst 1586779990.9821239
# zlib_sol_01.py 1586537193.4545062
# zlib.ipynb 1586558220.1601608
# http_server.rst 1586807866.1988044
# timeit.rst 1586901232.285203
# random.rst 1586806851.3102744
# lorem.txt 1586551738.0938718
# files.backup 1586731814.1699924
# .ipynb_checkpoints 1586900610.7107418
# difflib.rst 1586863058.5639656
# csv.rst 1586807008.1102073
# logging.rst 1586794797.0051491
# base64.rst 1585560535.2532449
# pdb.rst 1586803516.442853
# logging.ipynb 1586797109.578923
# os.rst 1583172967.7267907
# itertools.ipynb 1586793258.9420826
# gzip.ipynb 1586733318.2564354
# collections.rst 1586806733.9419165

# %% [markdown]
# -   `os.path.splitext(path)`: Devuelve una tupla de dos elementos (root,
#   ext). En la primera posición va la ruta completa del fichero, sin
#   extensión, y en la segunda va la extension, de forma que `path` ==
#   `root + ext`.

# %%
name, ext = os.path.splitext("README.txt")
print(name)
print(ext)
# Out:
# README
# .txt

# %%
# !tree
# Out:
# .
# ├── archivo
# │   ├── 2018
# │   │   ├── dic
# │   │   └── nov
# │   │       └── fac01.txt
# │   ├── 2019
# │   │   ├── dec
# │   │   ├── ene
# │   │   ├── feb
# │   │   │   └── fac22.txt
# │   │   └── nov
# │   └── 2020
# │       └── ene
# │           └── fac23.txt
# ├── os.ipynb
# ├── os.md
# └── os.rst
#
# 11 directories, 6 files

# %%
os.listdir('archivo')
# Out:
# ['2018', '2019', '2020']

# %% [markdown]
# ### os.path.walk

# %% [markdown]
# -   `os.walk(top, topdown=True, onerror=None, followlinks=False)` :
#     Devuelve un iterador que nos permite examinar todo un sistema de
#     archivos.

# %% [markdown]
# Para cada directorio y subdirectorio en la raíz (indicada
#     por `top`), incluyendo la propia raíz, el iterador devuelte una
#     tupla de tres elementos (normalmente llamados `dirpath`, `dirnames`
#     y `filenames`)

# %% [markdown]
# - `dirpath` es una cadena de texto, la ruta del directorio
#
# - `dirnames` es una lista con los nombres de los
#     subdirectorios dentro de `dirpath` (excluyendo los nombres
#     especiales . y ..)
#
# - `filenames` es una lista de nombres de los ficheros que **no** son un directorio en `dirpath`.
#
# En cualquier momento podemos tener una ruta absoluta a un archivo `f` en
#     `filenames` haciendo `os.path.join(top, dirpath, f)`.

# %%
for dirpath, dirs, files in os.walk("/home/jileon"):
    for f in files:
        if f.endswith('.txt'):
            print(f"Fichero {f} en {dirpath}")
# Out:
# Fichero chunk.txt en /home/jileon
# Fichero imagen.b64.txt en /home/jileon
# Fichero humans.txt en /home/jileon/wwwroot
# Fichero test_simple_pages.txt en /home/jileon/wwwroot
# Fichero robots.txt en /home/jileon/wwwroot
# Fichero requirements.txt en /home/jileon/wwwroot
# Fichero todo.txt en /home/jileon/wwwroot/suscripcion
# Fichero presiden_vil.txt en /home/jileon/wwwroot/composicion
# Fichero grupos_viil.txt en /home/jileon/wwwroot/composicion
# Fichero comisiones_vl.txt en /home/jileon/wwwroot/composicion
# Fichero presiden_vl.txt en /home/jileon/wwwroot/composicion
# Fichero grupos_vl.txt en /home/jileon/wwwroot/composicion
# Fichero grupos_ivl.txt en /home/jileon/wwwroot/composicion
# Fichero comisiones_ivl.txt en /home/jileon/wwwroot/composicion
# Fichero presiden_ivl.txt en /home/jileon/wwwroot/composicion
# Fichero grupos_vil.txt en /home/jileon/wwwroot/composicion
# Fichero comisiones_vil.txt en /home/jileon/wwwroot/composicion
# Fichero last-message.txt en /home/jileon/wwwroot/.hg
# Fichero jornadas.txt en /home/jileon/wwwroot/noticias
# Fichero analisis_global.txt en /home/jileon/wwwroot/eventos/constitucion_europea
# Fichero accion_exterior.txt en /home/jileon/wwwroot/eventos/constitucion_europea
# Fichero inauguracion.txt en /home/jileon/wwwroot/eventos/constitucion_europea
# Fichero clausura.txt en /home/jileon/wwwroot/eventos/constitucion_europea
# Fichero jornadas.txt en /home/jileon/wwwroot/eventos/constitucion_europea
# Fichero reforma_institucional.txt en /home/jileon/wwwroot/eventos/constitucion_europea
# Fichero europa_ampliada.txt en /home/jileon/wwwroot/eventos/constitucion_europea
# Fichero aspectos_economicos.txt en /home/jileon/wwwroot/eventos/constitucion_europea
# Fichero texto.txt en /home/jileon/wwwroot/25
# Fichero estatuto1982.txt en /home/jileon/wwwroot/25
# Fichero reforma1996.txt en /home/jileon/wwwroot/25
# Fichero tv.txt en /home/jileon/wwwroot/reuniones
# Fichero lista.txt en /home/jileon/wwwroot/images/tv
# Fichero SiteSecurityServiceState.txt en /home/jileon/.thunderbird/pfhciw4m.default
# Fichero SecurityPreloadState.txt en /home/jileon/.thunderbird/pfhciw4m.default
# Fichero pkcs11.txt en /home/jileon/.thunderbird/pfhciw4m.default
# Fichero AlternateServices.txt en /home/jileon/.thunderbird/pfhciw4m.default
# Fichero revocations.txt en /home/jileon/.thunderbird/pfhciw4m.default
# Fichero Telemetry.ShutdownTime.txt en /home/jileon/.thunderbird/pfhciw4m.default
# Fichero s.txt en /home/jileon/temp/acl
# Fichero abreviaturas.txt en /home/jileon/temp/acl
# Fichero v.txt en /home/jileon/temp/acl
# Fichero presentacion.txt en /home/jileon/temp/acl
# Fichero done.txt en /home/jileon/temp/acl
# Fichero j.txt en /home/jileon/temp/acl
# Fichero flora.txt en /home/jileon/temp/acl
# Fichero f.txt en /home/jileon/temp/acl
# Fichero informe_final_2014.txt en /home/jileon/temp/acl
# Fichero dev-requirements.txt en /home/jileon/temp/acl
# Fichero g.txt en /home/jileon/temp/acl
# Fichero t.txt en /home/jileon/temp/acl
# Fichero fauna.txt en /home/jileon/temp/acl
# Fichero e.txt en /home/jileon/temp/acl
# Fichero b.txt en /home/jileon/temp/acl
# Fichero p.txt en /home/jileon/temp/acl
# Fichero n.txt en /home/jileon/temp/acl
# Fichero i.txt en /home/jileon/temp/acl
# Fichero ñ.txt en /home/jileon/temp/acl
# Fichero informe.txt en /home/jileon/temp/acl
# Fichero y.txt en /home/jileon/temp/acl
# Fichero notas.txt en /home/jileon/temp/acl
# Fichero z.txt en /home/jileon/temp/acl
# Fichero u.txt en /home/jileon/temp/acl
# Fichero m.txt en /home/jileon/temp/acl
# Fichero o.txt en /home/jileon/temp/acl
# Fichero d.txt en /home/jileon/temp/acl
# Fichero l.txt en /home/jileon/temp/acl
# Fichero r.txt en /home/jileon/temp/acl
# Fichero c.txt en /home/jileon/temp/acl
# Fichero todo.txt en /home/jileon/temp/acl
# Fichero a.txt en /home/jileon/temp/acl
# Fichero q.txt en /home/jileon/temp/acl
# Fichero h.txt en /home/jileon/temp/acl
# Fichero requirements.txt en /home/jileon/temp/acl
# Fichero nuevo_comentario.txt en /home/jileon/temp/acl/diccionario/templates/diccionario
# Fichero credits.txt en /home/jileon/temp/acl/media/skins/tango
# Fichero credits.txt en /home/jileon/temp/acl/media/skins/ie7
# Fichero presentacion.txt en /home/jileon/temp/acl/docs
# Fichero nueva_consulta.txt en /home/jileon/temp/acl/consultas/templates/consultas
# Fichero gracias.txt en /home/jileon/temp/acl/consultas/templates/consultas
# Fichero libreq.txt en /home/jileon/web
# Fichero cgireq.txt en /home/jileon/web
# Fichero wwwreq.txt en /home/jileon/web
# Fichero humans.txt en /home/jileon/web/wwwroot
# Fichero test_simple_pages.txt en /home/jileon/web/wwwroot
# Fichero robots.txt en /home/jileon/web/wwwroot
# Fichero requirements.txt en /home/jileon/web/wwwroot
# Fichero todo.txt en /home/jileon/web/wwwroot/suscripcion
# Fichero presiden_vil.txt en /home/jileon/web/wwwroot/composicion
# Fichero grupos_viil.txt en /home/jileon/web/wwwroot/composicion
# Fichero comisiones_vl.txt en /home/jileon/web/wwwroot/composicion
# Fichero presiden_vl.txt en /home/jileon/web/wwwroot/composicion
# Fichero grupos_vl.txt en /home/jileon/web/wwwroot/composicion
# Fichero grupos_ivl.txt en /home/jileon/web/wwwroot/composicion
# Fichero comisiones_ivl.txt en /home/jileon/web/wwwroot/composicion
# Fichero presiden_ivl.txt en /home/jileon/web/wwwroot/composicion
# Fichero grupos_vil.txt en /home/jileon/web/wwwroot/composicion
# Fichero comisiones_vil.txt en /home/jileon/web/wwwroot/composicion
# Fichero jornadas.txt en /home/jileon/web/wwwroot/noticias
# Fichero analisis_global.txt en /home/jileon/web/wwwroot/eventos/constitucion_europea
# Fichero accion_exterior.txt en /home/jileon/web/wwwroot/eventos/constitucion_europea
# Fichero inauguracion.txt en /home/jileon/web/wwwroot/eventos/constitucion_europea
# Fichero clausura.txt en /home/jileon/web/wwwroot/eventos/constitucion_europea
# Fichero jornadas.txt en /home/jileon/web/wwwroot/eventos/constitucion_europea
# Fichero reforma_institucional.txt en /home/jileon/web/wwwroot/eventos/constitucion_europea
# Fichero europa_ampliada.txt en /home/jileon/web/wwwroot/eventos/constitucion_europea
# Fichero aspectos_economicos.txt en /home/jileon/web/wwwroot/eventos/constitucion_europea
# Fichero texto.txt en /home/jileon/web/wwwroot/25
# Fichero estatuto1982.txt en /home/jileon/web/wwwroot/25
# Fichero reforma1996.txt en /home/jileon/web/wwwroot/25
# Fichero tv.txt en /home/jileon/web/wwwroot/reuniones
# Fichero lista.txt en /home/jileon/web/wwwroot/images/tv
# Fichero Seguridad.txt en /home/jileon/web/Libreria
# Fichero requirements.txt en /home/jileon/web/Libreria
# Fichero Genesis.txt en /home/jileon/web/Libreria/Utilidades
# Fichero requirements.txt en /home/jileon/web/parcanweb
# Fichero tv.txt en /home/jileon/web/parcanweb/tv
# Fichero requirements.txt en /home/jileon/web/cgi-bin
# Fichero enmiendas.txt en /home/jileon/web/cgi-bin/presupuesto/publicaciones
# Fichero relacionadas.txt en /home/jileon/web/cgi-bin/presupuesto/listados
# Fichero done.txt en /home/jileon/web/cgi-bin/noticias
# Fichero todo.txt en /home/jileon/web/cgi-bin/noticias
# Fichero colores.txt en /home/jileon/web/cgi-bin/agenda_mnto
# Fichero plantilla_parte.txt en /home/jileon/web/cgi-bin/material
# Fichero freefontsdownload.txt en /home/jileon/.themes/iOS-X/cinnamon/fonts/helveticaneue
# Fichero relacion_fotos_paginas.txt en /home/jileon/Documentos/Fotos/Peritajes 2017
# Fichero Bleeding-Dragon's Old papers.txt en /home/jileon/Documentos/Art/Texturas/Bleeding Dragon Old Papers
# Fichero misc_ascii2.php.txt en /home/jileon/Documentos/Art/Laura
# Fichero BLENDSWAP_LICENSE.txt en /home/jileon/Documentos/Blender/MF2/48469_Millennium_Falcon___High_Poly_
# Fichero readme.txt en /home/jileon/Documentos/Blender/1960Batmobile
# Fichero readme.txt en /home/jileon/Documentos/Juegos/Designing_Arcade_Computer_Game_Graphics
# Fichero ._readme.txt en /home/jileon/Documentos/Juegos/Designing_Arcade_Computer_Game_Graphics
# Fichero A_ LEER ANTES DE IMPRIMIR JUGAR.txt en /home/jileon/Documentos/Juegos/Detective Rufián
# Fichero Liberation Fonts License Terms.txt en /home/jileon/Documentos/Fuentes
# Fichero Content_[1103].txt en /home/jileon/Documentos/Fuentes/Top40 - MyFonts.com
# Fichero ZReadMe.txt en /home/jileon/Documentos/Fuentes/Top40 - MyFonts.com/Linotype Zapfino
# Fichero cacheSize.txt en /home/jileon/.adobe/Flash_Player/AssetCache/CVHVA7WS
# Fichero cookies.txt en /home/jileon/.adobe/Acrobat/9.0/Cache
# Fichero SiteSecurityServiceState.txt en /home/jileon/.mozilla/firefox/mwad0hks.default
# Fichero enumerate_devices.txt en /home/jileon/.mozilla/firefox/mwad0hks.default
# Fichero SecurityPreloadState.txt en /home/jileon/.mozilla/firefox/mwad0hks.default
# Fichero pkcs11.txt en /home/jileon/.mozilla/firefox/mwad0hks.default
# Fichero cert_override.txt en /home/jileon/.mozilla/firefox/mwad0hks.default
# Fichero AlternateServices.txt en /home/jileon/.mozilla/firefox/mwad0hks.default
# Fichero serviceworker.txt en /home/jileon/.mozilla/firefox/mwad0hks.default
# Fichero TRRBlacklist.txt en /home/jileon/.mozilla/firefox/mwad0hks.default
# Fichero LICENSE.txt en /home/jileon/.mozilla/firefox/mwad0hks.default/gmp-widevinecdm/4.10.1582.2
# Fichero SiteSecurityServiceState.txt en /home/jileon/.mozilla/firefox/pmjl3rnx.default-esr
# Fichero SecurityPreloadState.txt en /home/jileon/.mozilla/firefox/pmjl3rnx.default-esr
# Fichero pkcs11.txt en /home/jileon/.mozilla/firefox/pmjl3rnx.default-esr
# Fichero AlternateServices.txt en /home/jileon/.mozilla/firefox/pmjl3rnx.default-esr
# Fichero revocations.txt en /home/jileon/.mozilla/firefox/pmjl3rnx.default-esr
# Fichero TRRBlacklist.txt en /home/jileon/.mozilla/firefox/pmjl3rnx.default-esr
# Fichero SiteSecurityServiceState.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release
# Fichero enumerate_devices.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release
# Fichero SecurityPreloadState.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release
# Fichero pkcs11.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release
# Fichero cert_override.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release
# Fichero AlternateServices.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release
# Fichero serviceworker.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release
# Fichero TRRBlacklist.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release
# Fichero LICENSE.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/gmp-widevinecdm/4.10.1582.2
# Fichero error-sync-1601711756469.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601879043532.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601717903577.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1602076832969.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601717801449.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601878949144.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601749725639.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601849159788.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1602227611879.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601773800139.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601795784190.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601939931469.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601937636394.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601750592213.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601839816818.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601826905906.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero error-sync-1601750095472.txt en /home/jileon/.mozilla/firefox/9oj1gfjf.default-release/weave/logs
# Fichero uid.txt en /home/jileon/.android
# Fichero Seguridad.txt en /home/jileon/Libreria
# Fichero requirements.txt en /home/jileon/Libreria
# Fichero last-message.txt en /home/jileon/Libreria/.hg
# Fichero Genesis.txt en /home/jileon/Libreria/Utilidades
# Fichero resthumb-d5c236c9a82030e997553cf356976e9f.txt en /home/jileon/.godot/tmp
# Fichero resthumb-33180094f768a179b4d9adf13b529bf7.txt en /home/jileon/.godot/tmp
# Fichero resthumb-276d67d58f362fe430d96577227253aa.txt en /home/jileon/.godot/tmp
# Fichero resthumb-1e3043120b504946c1b19f98eadf5597.txt en /home/jileon/.godot/tmp
# Fichero resthumb-0e1de84368b629604b1b7d35c11a668e.txt en /home/jileon/.godot/tmp
# Fichero resthumb-1c41d6e9f777dc81eb1cd587a4ab8e25.txt en /home/jileon/.godot/tmp
# Fichero resthumb-ce61774b8f37983ca94fd93f250da96e.txt en /home/jileon/.godot/tmp
# Fichero resthumb-40260bb26c746d7ceae26b7436afcff9.txt en /home/jileon/.godot/tmp
# Fichero resthumb-63f65a6bc0322809e189ca9d95465f6e.txt en /home/jileon/.godot/tmp
# Fichero resthumb-b3a866f95c1eecc5d07a48ae67f83e01.txt en /home/jileon/.godot/tmp
# Fichero resthumb-0bd22c8a737c193ddf772d85ce074a7b.txt en /home/jileon/.godot/tmp
# Fichero resthumb-9250b90e7ff6dab73b1de1a671e5f901.txt en /home/jileon/.godot/tmp
# Fichero resthumb-92e88977d3da52e6e200fc83691676b2.txt en /home/jileon/.godot/tmp
# Fichero resthumb-fa17ac2a59cec5d78b67a89e797d9bb8.txt en /home/jileon/.godot/tmp
# Fichero resthumb-7ee910e5bcd367bfb6c4cd62eb583957.txt en /home/jileon/.godot/tmp
# Fichero resthumb-d71dffe0357551ea6751c37e46e5de90.txt en /home/jileon/.godot/tmp
# Fichero resthumb-03eff258c568f81db6e5df6e2fcb9edb.txt en /home/jileon/.godot/tmp
# Fichero resthumb-1320bff1aaa205e3af78a18521330aa3.txt en /home/jileon/.godot/tmp
# Fichero resthumb-d5e2e9c391dad3f65014d1f2430f749e.txt en /home/jileon/.godot/tmp
# Fichero resthumb-260931699ef40b686a0b79c65c97d413.txt en /home/jileon/.godot/tmp
# Fichero resthumb-c1273058662e4d39df219d53e3a9421e.txt en /home/jileon/.godot/tmp
# Fichero resthumb-68d06ac405bd95702771ebe6e1a5caa6.txt en /home/jileon/.godot/tmp
# Fichero resthumb-49f116b3878df37dc575c2168dffbd45.txt en /home/jileon/.godot/tmp
# Fichero resthumb-a6e4506845ffd1b0c7810ecc3dc34ed5.txt en /home/jileon/.godot/tmp
# Fichero resthumb-2ad567982e6b0cd0bfbd53c6fa2930d2.txt en /home/jileon/.godot/tmp
# Fichero resthumb-bd4adbfffcda4e61d3cacc5bd7fd0f6d.txt en /home/jileon/.godot/tmp
# Fichero bootstrap_log.txt en /home/jileon/Steam/logs
# Fichero no-global-site-packages.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5
# Fichero orig-prefix.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5
# Fichero top_level.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/pytz-2017.2.dist-info
# Fichero top_level.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/setuptools-36.2.0.dist-info
# Fichero entry_points.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/setuptools-36.2.0.dist-info
# Fichero dependency_links.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/setuptools-36.2.0.dist-info
# Fichero top_level.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/pip-9.0.1.dist-info
# Fichero entry_points.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/pip-9.0.1.dist-info
# Fichero eggnames.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/wheel
# Fichero top_level.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/wheel-0.29.0.dist-info
# Fichero LICENSE.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/wheel-0.29.0.dist-info
# Fichero entry_points.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/wheel-0.29.0.dist-info
# Fichero top_level.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/Django-1.11.3.dist-info
# Fichero LICENSE.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/Django-1.11.3.dist-info
# Fichero entry_points.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/Django-1.11.3.dist-info
# Fichero license.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/django/dispatch
# Fichero README.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/django/contrib/admin/static/admin/img
# Fichero LICENSE.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/django/contrib/admin/static/admin/fonts
# Fichero README.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/django/contrib/admin/static/admin/fonts
# Fichero LICENSE-XREGEXP.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/django/contrib/admin/static/admin/js/vendor/xregexp
# Fichero LICENSE-JQUERY.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/django/contrib/admin/static/admin/js/vendor/jquery
# Fichero password_reset_subject.txt en /home/jileon/Lab/lab-prefetch/.vent/lib/python3.5/site-packages/django/contrib/auth/templates/registration
# Fichero untitled-checkpoint.txt en /home/jileon/.ipynb_checkpoints
# Fichero ChangeLog.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Docs
# Fichero Noto-CJK-Font.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Docs/Licenses
# Fichero Tor-Launcher.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Docs/Licenses
# Fichero NoScript.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Docs/Licenses
# Fichero Libevent.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Docs/Licenses
# Fichero Torbutton.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Docs/Licenses
# Fichero Noto-Fonts.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Docs/Licenses
# Fichero Tor.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Docs/Licenses
# Fichero Firefox.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Docs/Licenses
# Fichero HTTPS-Everywhere.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Docs/Licenses
# Fichero SiteSecurityServiceState.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Data/Browser/profile.default
# Fichero SecurityPreloadState.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Data/Browser/profile.default
# Fichero AlternateServices.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Data/Browser/profile.default
# Fichero TRRBlacklist.txt en /home/jileon/Descargas/tor-browser_en-US/Browser/TorBrowser/Data/Browser/profile.default
# Fichero tags.txt en /home/jileon/Archivo/2018/Oferta Educativa
# Fichero Fasta_format.txt en /home/jileon/Archivo/2018/Oferta Educativa
# Fichero cita.txt en /home/jileon/Archivo/2016/UnaImagenValeMasQueMilMentiras
# Fichero notas.txt en /home/jileon/Archivo/2016/Madrid Boda Jose/Alojamiento
# Fichero notas.txt en /home/jileon/Archivo/2014/PyConEs2014
# Fichero resumen.txt en /home/jileon/Archivo/2014/Agile Canarias 2014
# Fichero carta_a_jeronimo.txt en /home/jileon/Archivo/2014/Agile Canarias 2014
# Fichero parlamento.txt en /home/jileon/Archivo/2015/PyConEs2015
# Fichero ejemplo2.txt en /home/jileon/Archivo/2015/PyConEs2015/code
# Fichero ejemplo1.txt en /home/jileon/Archivo/2015/PyConEs2015/code
# Fichero ejemplo3.txt en /home/jileon/Archivo/2015/PyConEs2015/code
# Fichero ejemplo_ext_ll1.txt en /home/jileon/Archivo/2015/PyConEs2015/code
# Fichero done.txt en /home/jileon/Archivo/2015/PyConEs2015/grafel
# Fichero todo.txt en /home/jileon/Archivo/2015/PyConEs2015/grafel
# Fichero requirements.txt en /home/jileon/Archivo/2015/PyConEs2015/grafel
# Fichero last-message.txt en /home/jileon/Archivo/2015/PyConEs2015/grafel/.hg
# Fichero tablas-moodle.txt en /home/jileon/Archivo/2010/pincel
# Fichero 009_user_classes.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 013_Dynamically_Loaded_Modules.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 010_First_class_everything.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 011_How_everything_become_an_executable_statment.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 008_Python_Use_of_Dynamic_Typing.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 012_Integer_division.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 002_design.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 016_And_the_Snake_Attacks.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 001_intro_and_overview.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 005_personal_history_2.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 004_personal_history_1.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 017_Metaclass_and_extension_classes.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 04_personal_history_1.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero intro_and_overview.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 014_The_Great_Renaming.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 003_timeline.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 006_Microsoft_ships_python.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 007_Early_Language_Design_and_Development.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero 015_Origins_of_Python_Functional_Features.txt en /home/jileon/Archivo/2009/Historia de Python
# Fichero BLENDSWAP_LICENSE.txt en /home/jileon/Archivo/2017/EMDS Party/65673_imperial_AT-ST
# Fichero BLENDSWAP_LICENSE.txt en /home/jileon/Archivo/2017/EMDS Party/66514_AT-AT_walker
# Fichero requirements.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP
# Fichero no-global-site-packages.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5
# Fichero orig-prefix.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5
# Fichero top_level.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/wheel-0.30.0a0.dist-info
# Fichero LICENSE.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/wheel-0.30.0a0.dist-info
# Fichero entry_points.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/wheel-0.30.0a0.dist-info
# Fichero top_level.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/setuptools-36.2.0.dist-info
# Fichero entry_points.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/setuptools-36.2.0.dist-info
# Fichero dependency_links.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/setuptools-36.2.0.dist-info
# Fichero top_level.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/pip-9.0.1.dist-info
# Fichero entry_points.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/pip-9.0.1.dist-info
# Fichero eggnames.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/wheel
# Fichero top_level.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/pyparsing-2.2.0.dist-info
# Fichero top_level.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/py-1.4.34.dist-info
# Fichero LICENSE.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/py-1.4.34.dist-info
# Fichero top_level.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/termcolor-1.1.0.dist-info
# Fichero top_level.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/pytest-3.1.3.dist-info
# Fichero LICENSE.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/pytest-3.1.3.dist-info
# Fichero entry_points.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/pytest-3.1.3.dist-info
# Fichero top_level.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/pytest_sugar-0.8.0.dist-info
# Fichero entry_points.txt en /home/jileon/Archivo/2017/Charla-DSL-en-FLP/.venv/lib/python3.5/site-packages/pytest_sugar-0.8.0.dist-info
# Fichero mensajes-telegram.txt en /home/jileon/Archivo/2017/Peritaje_js2_maritimo
# Fichero correos-122.txt en /home/jileon/Archivo/2017/Peritaje_js2_maritimo
# Fichero correo-ejemplo.txt en /home/jileon/Archivo/2017/Peritaje_js2_maritimo
# Fichero ejemplo-envio-cliente-empresa.txt en /home/jileon/Archivo/2017/Peritaje_js2_maritimo
# Fichero correos-116.txt en /home/jileon/Archivo/2017/Peritaje_js2_maritimo
# Fichero correos-118.txt en /home/jileon/Archivo/2017/Peritaje_js2_maritimo
# Fichero correo-112-113.txt en /home/jileon/Archivo/2017/Peritaje_js2_maritimo
# Fichero correo-84.txt en /home/jileon/Archivo/2017/Peritaje_js2_maritimo
# Fichero correo-107-108.txt en /home/jileon/Archivo/2017/Peritaje_js2_maritimo
# Fichero correo-80-81-82.txt en /home/jileon/Archivo/2017/Peritaje_js2_maritimo
# Fichero correos-117.txt en /home/jileon/Archivo/2017/Peritaje_js2_maritimo
# Fichero trascripcion-hangup-26-nov-2012.txt en /home/jileon/Archivo/2013/PyconEs2013
# Fichero checklist.txt en /home/jileon/Archivo/2013/PyconEs2013
# Fichero direccion-jose.txt en /home/jileon/Archivo/2013/PyconEs2013
# Fichero direccion-javi.txt en /home/jileon/Archivo/2013/PyconEs2013
# Fichero datos_vuelos.txt en /home/jileon/Archivo/2013/PyconEs2013
# Fichero notes.txt en /home/jileon/Archivo/2013/M102: MongoDB for DBAs
# Fichero quizes.txt en /home/jileon/Archivo/2013/MongoDB/hw5
# Fichero analisis-d.txt en /home/jileon/Archivo/2013/Platino2
# Fichero notas.txt en /home/jileon/Archivo/2013/Platino2
# Fichero temario.txt en /home/jileon/Archivo/2013/Curso Python IAC
# Fichero parcan.txt en /home/jileon/Archivo/2013/Curso Python IAC
# Fichero ejercicios.txt en /home/jileon/Archivo/2013/Curso Python IAC
# Fichero programa.txt en /home/jileon/Archivo/2013/Curso Python IAC
# Fichero invitados.txt en /home/jileon/Archivo/2013/Curso Python IAC
# Fichero preguntas.txt en /home/jileon/Archivo/2013/Curso Python IAC
# Fichero personal_iac.txt en /home/jileon/Archivo/2013/Curso Python IAC
# Fichero recomendaciones_alumos.txt en /home/jileon/Archivo/2013/Curso Python IAC
# Fichero mapa.txt en /home/jileon/Archivo/2013/Curso Python IAC
# Fichero zen.txt en /home/jileon/Archivo/2013/Curso Python IAC
# Fichero Quotes about Python.txt en /home/jileon/Archivo/2013/Curso Python IAC/recursos
# Fichero last-message.txt en /home/jileon/Archivo/2013/Curso Python IAC/.hg
# Fichero optionsof.txt en /home/jileon/.minecraft
# Fichero launcher_log.txt en /home/jileon/.minecraft
# Fichero options.txt en /home/jileon/.minecraft
# Fichero optionsshaders.txt en /home/jileon/.minecraft
# Fichero mcp_config-1.14.4-20190829.143755-mappings.txt en /home/jileon/.minecraft/libraries/de/oceanlabs/mcp/mcp_config/1.14.4-20190829.143755
# Fichero mixin_implementation_report.txt en /home/jileon/.minecraft/.mixin.out/audit
# Fichero !read-me.txt en /home/jileon/.minecraft/tv-cache
# Fichero crash-2020-03-05_20.10.06-client.txt en /home/jileon/.minecraft/crash-reports
# Fichero players.txt en /home/jileon/.minecraft/local/ftbutilities
# Fichero ranks.txt en /home/jileon/.minecraft/local/ftbutilities
# Fichero BIKF-cache.txt en /home/jileon/.fgfs/ai/B/I/K
# Fichero LELL-cache.txt en /home/jileon/.fgfs/ai/L/E/L
# Fichero =+usr=+share=+vim=+vim74=+doc=+help.txt en /home/jileon/.cache/neocomplcache/buffer_cache
# Fichero =+usr=+share=+vim=+vim74=+doc=+help.txt en /home/jileon/.cache/neocomplcache/keyword_patterns
# Fichero %home%jileon%workarea%acl.txt en /home/jileon/.cache/ctrlp
# Fichero cache.txt en /home/jileon/.cache/ctrlp/mru
# Fichero cache.txt en /home/jileon/.cache/ctrlp/hist
# Fichero requirements-dev.txt en /home/jileon/.cache/pre-commit/repo2a89evlv
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/powrap.egg-info
# Fichero SOURCES.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/powrap.egg-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/powrap.egg-info
# Fichero dependency_links.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/powrap.egg-info
# Fichero requires.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/powrap.egg-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/setuptools-46.1.3.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/setuptools-46.1.3.dist-info
# Fichero dependency_links.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/setuptools-46.1.3.dist-info
# Fichero vendor.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/pip/_vendor
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/wheel-0.34.2.dist-info
# Fichero LICENSE.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/wheel-0.34.2.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/wheel-0.34.2.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/tqdm-4.46.0.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/tqdm-4.46.0.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/pip-20.1.dist-info
# Fichero LICENSE.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/pip-20.1.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/pip-20.1.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/powrap-0.3.1.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo2a89evlv/py_env-python3/lib/python3.6/site-packages/powrap-0.3.1.dist-info
# Fichero requirements-dev.txt en /home/jileon/.cache/pre-commit/repob0qehu5b
# Fichero nonsense.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/testing/resources
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/zipp-3.1.0.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/setuptools-46.1.3.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/setuptools-46.1.3.dist-info
# Fichero dependency_links.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/setuptools-46.1.3.dist-info
# Fichero namespace_packages.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/pycodestyle-2.6.0.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/pycodestyle-2.6.0.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/pycodestyle-2.6.0.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/pyflakes-2.2.0.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/pyflakes-2.2.0.dist-info
# Fichero vendor.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/pip/_vendor
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/wheel-0.34.2.dist-info
# Fichero LICENSE.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/wheel-0.34.2.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/wheel-0.34.2.dist-info
# Fichero namespace_packages.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/ruamel.yaml-0.16.10.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/ruamel.yaml-0.16.10.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/six-1.14.0.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/pip-20.1.dist-info
# Fichero LICENSE.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/pip-20.1.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/pip-20.1.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/flake8-3.8.1.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/flake8-3.8.1.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/mccabe-0.6.1.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/mccabe-0.6.1.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/pre_commit_hooks-2.5.0.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/pre_commit_hooks-2.5.0.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/importlib_metadata-1.6.0.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/toml-0.10.1.dist-info
# Fichero LICENSE.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/toml-0.10.1.dist-info
# Fichero namespace_packages.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/ruamel.yaml.clib-0.2.0.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/ruamel.yaml.clib-0.2.0.dist-info
# Fichero LICENSE.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/py_env-python3/lib/python3.6/site-packages/ruamel.yaml.clib-0.2.0.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/pre_commit_hooks.egg-info
# Fichero SOURCES.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/pre_commit_hooks.egg-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/pre_commit_hooks.egg-info
# Fichero dependency_links.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/pre_commit_hooks.egg-info
# Fichero requires.txt en /home/jileon/.cache/pre-commit/repob0qehu5b/pre_commit_hooks.egg-info
# Fichero requirements-dev.txt en /home/jileon/.cache/pre-commit/repo761zqnbh
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/powrap.egg-info
# Fichero SOURCES.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/powrap.egg-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/powrap.egg-info
# Fichero dependency_links.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/powrap.egg-info
# Fichero requires.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/powrap.egg-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/setuptools-46.1.3.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/setuptools-46.1.3.dist-info
# Fichero dependency_links.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/setuptools-46.1.3.dist-info
# Fichero vendor.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/pip/_vendor
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/wheel-0.34.2.dist-info
# Fichero LICENSE.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/wheel-0.34.2.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/wheel-0.34.2.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/tqdm-4.46.0.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/tqdm-4.46.0.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/pip-20.1.dist-info
# Fichero LICENSE.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/pip-20.1.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/pip-20.1.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/powrap-0.3.1.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo761zqnbh/py_env-python3/lib/python3.6/site-packages/powrap-0.3.1.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/setuptools-46.1.3.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/setuptools-46.1.3.dist-info
# Fichero dependency_links.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/setuptools-46.1.3.dist-info
# Fichero template.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/writers/html5_polyglot
# Fichero README.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/writers/s5_html/themes
# Fichero template.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/writers/html4css1
# Fichero template.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/writers/pep_html
# Fichero isocyr1.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isonum.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isogrk2.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero xhtml1-special.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isoamsa.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isomopf-wide.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isogrk4-wide.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isoamso.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero s5defs.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isogrk4.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isoamsn.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero mmlextra.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero xhtml1-symbol.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isoamsc.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero xhtml1-lat1.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isoamsr.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isomscr.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isomscr-wide.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isolat1.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isodia.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero mmlextra-wide.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isogrk1.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isomopf.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isoamsb.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isotech.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isogrk3.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero mmlalias.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero README.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isobox.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isopub.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isomfrk-wide.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isocyr2.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isolat2.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero isomfrk.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils/parsers/rst/include
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/regex-2020.5.14.dist-info
# Fichero vendor.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/pip/_vendor
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/wheel-0.34.2.dist-info
# Fichero LICENSE.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/wheel-0.34.2.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/wheel-0.34.2.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/pospell-1.0.3.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/pospell-1.0.3.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/polib-1.1.0.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/pip-20.1.dist-info
# Fichero LICENSE.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/pip-20.1.dist-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/pip-20.1.dist-info
# Fichero COPYING.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils-0.16.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/py_env-python3/lib/python3.6/site-packages/docutils-0.16.dist-info
# Fichero top_level.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/pospell.egg-info
# Fichero SOURCES.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/pospell.egg-info
# Fichero entry_points.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/pospell.egg-info
# Fichero dependency_links.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/pospell.egg-info
# Fichero requires.txt en /home/jileon/.cache/pre-commit/repo2ce92lof/pospell.egg-info
# Fichero resthumb-708a281131f1693e84d913ac737c7b15.txt en /home/jileon/.cache/godot
# Fichero resthumb-2b063b7d8e1108688efc49a74f28b2af.txt en /home/jileon/.cache/godot
# Fichero resthumb-01873c3562db88a0c971e2eaccb20a70.txt en /home/jileon/.cache/godot
# Fichero resthumb-279dd329c6817cf0fe13243f54a71140.txt en /home/jileon/.cache/godot
# Fichero resthumb-69cffcf58f4cbaeb35138de30a4c3f68.txt en /home/jileon/.cache/godot
# Fichero resthumb-953ba059d32197da343548357e18de1d.txt en /home/jileon/.cache/godot
# Fichero resthumb-66d1e3be2e33d4c6d2143684e9e6de96.txt en /home/jileon/.cache/godot
# Fichero resthumb-c48fb87de8765f33bdb975a8c990f980.txt en /home/jileon/.cache/godot
# Fichero resthumb-3f998a8086e583f022343f23f7983144.txt en /home/jileon/.cache/godot
# Fichero resthumb-06179ea66148a0199b7a2ded20afda46.txt en /home/jileon/.cache/godot
# Fichero resthumb-58ca7ba7fe49c7f9eb448115518928f0.txt en /home/jileon/.cache/godot
# Fichero resthumb-8c35fe5c5a01cf5577e81d0927e07fbb.txt en /home/jileon/.cache/godot
# Fichero resthumb-1b3d19ead4fe47065122080f6f7e9d4a.txt en /home/jileon/.cache/godot
# Fichero resthumb-339a85983de2bf29afce3881905b44c2.txt en /home/jileon/.cache/godot
# Fichero resthumb-ab0a4bac345b519c0cf180257ab9d27d.txt en /home/jileon/.cache/godot
# Fichero resthumb-3d82cdd13b6c14341fcf0f5b47e4251b.txt en /home/jileon/.cache/godot
# Fichero resthumb-881503f6ac6084194c36a75413d45973.txt en /home/jileon/.cache/godot
# Fichero resthumb-e4a928c952233b99346310788d068057.txt en /home/jileon/.cache/godot
# Fichero resthumb-2077df30ccbcca186b52476855960a98.txt en /home/jileon/.cache/godot
# Fichero resthumb-99497ea2f2b1bcfe827f6be44ad14b02.txt en /home/jileon/.cache/godot
# Fichero resthumb-ee2d7aec3611ab63d8fa0b72060c41a3.txt en /home/jileon/.cache/godot
# Fichero resthumb-8bb10e59ffc3be3e2524a320a79a60cb.txt en /home/jileon/.cache/godot
# Fichero resthumb-48c65d6a071f79a8e7bfd321b8aa8e7a.txt en /home/jileon/.cache/godot
# Fichero resthumb-9c79c39b600684e37dca21362999850d.txt en /home/jileon/.cache/godot
# Fichero resthumb-30ccc133cb83331d4298d67096c7ff6c.txt en /home/jileon/.cache/godot
# Fichero resthumb-bda056edd97351bda3875d5b973ce917.txt en /home/jileon/.cache/godot
# Fichero resthumb-0efd237b106c89eee89c9073c1f31d36.txt en /home/jileon/.cache/godot
# Fichero resthumb-9d33698500495066dc773a53d63afeb1.txt en /home/jileon/.cache/godot
# Fichero resthumb-f99d47e2918bd83c33b334293d4e66e6.txt en /home/jileon/.cache/godot
# Fichero resthumb-45f33c8048badd1c88823c2fc5981154.txt en /home/jileon/.cache/godot
# Fichero resthumb-8919686e76aded4dc26a64a9421bfb26.txt en /home/jileon/.cache/godot
# Fichero resthumb-4977c5e1feba838f67ecc7d0b5c3b0c7.txt en /home/jileon/.cache/godot
# Fichero resthumb-229ba0abad706be82d582b03a2b0bc3c.txt en /home/jileon/.cache/godot
# ...
# Fichero SIL Open Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laurent/Theano-Old-Style
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/rosario
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/rosario
# Fichero SIL Open Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/Crimson
# Fichero Habibi SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/habibi
# Fichero License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/Romande ADF
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/Karla
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/Chivo
# Fichero SIL OFL Font License Chivo.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/Chivo
# Fichero NOTICE.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/MintSpirit-20120526
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/MintSpirit-20120526/OTF
# Fichero SIL OFL Font License Duru Sans.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/duru-sans
# Fichero ƒontInfo.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/Polaris
# Fichero SIL Open Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/tinos
# Fichero SIL OFL Font License Varela.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/varela-round
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/Lora
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/Merriweather
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/Merriweather
# Fichero Bree SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/bree-serif
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/magra
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/magra
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/bitter
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/bitter
# Fichero METADATA_comments.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/bitter/src
# Fichero LICENCE.txt en /home/jileon/font-specimens/fonts/fonts-perso/Patricio/NotCourierSans
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/Sorts_Mill_Goudy
# Fichero Bitstream Vera License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/Bitstream-Vera-Sans
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/quattrocento-sans
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/quattrocento-sans
# Fichero SIL OFL Font License Inder.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/inder
# Fichero Read me.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/Courier Prime
# Fichero OFL-FAQ.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/Courier Prime/LICENSE
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/Courier Prime/LICENSE
# Fichero Qattrocento SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/quattrocento-roman
# Fichero Cabin SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/cabin
# Fichero OT_TT_Install_E.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/PTSerif
# Fichero PT Free Font License_eng_1.2.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/PTSerif
# Fichero OT_TT_Install_R.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/PTSerif
# Fichero PT Free Font License_rus_1.2.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/PTSerif
# Fichero SIL OFL Font License Libre Baskerville.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/libre-baskerville
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/Univers Else
# Fichero OFL-FAQ.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/Univers Else
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/Univers Else
# Fichero README.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/Univers Else
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/Anaheim
# Fichero SIL OFL Font License Numans.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/numans
# Fichero SIL OFL Font License Judson.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/judson
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/Share_Tech_Mono
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Justine/Orienta
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/merienda
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/merienda
# Fichero METADATA_comments.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/merienda/src
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/Gentium_Basic
# Fichero Asap SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/asap
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/Cardo
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/signika/Signika
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/signika/Signika_Negative
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/DoulosSIL-4.112
# Fichero OFL-FAQ.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/DoulosSIL-4.112
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/DoulosSIL-4.112
# Fichero README.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/DoulosSIL-4.112
# Fichero DOCUMENTATION.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/DoulosSIL-4.112/documentation
# Fichero OFL-FAQ.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/LS
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/LS
# Fichero SIL OFL Font License Forum.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/forum
# Fichero Crete Round SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/crete-round
# Fichero SIL OFL Font License Trykker.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/trykker
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/Inconsolata
# Fichero SIL Open Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/Inconsolata
# Fichero LICENSE.txt en /home/jileon/font-specimens/fonts/fonts-perso/Noémie/Luxi Sans
# Fichero PT Mono SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/pt-mono
# Fichero COPYING.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/OSP_Logisoso
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/OSP_Logisoso
# Fichero SIL Open Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/merriweather
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/sedan
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/sedan
# Fichero METADATA_comments.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/sedan/src
# Fichero SIL OFL Cyreal.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/rationale
# Fichero Cheapskate Fonts License - Dustismo.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/Dustismo-Roman
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/newscycle
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/newscycle
# Fichero METADATA_comments.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/newscycle/src
# Fichero Ropa Sans SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/ropa-sans
# Fichero SIL Open Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/copse
# Fichero Flyerzone license.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/scifly
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/Antic_Slab
# Fichero Volkhov OFL SIL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/volkhov
# Fichero LICENSE.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/LM Sans 10
# Fichero GUST e-foundry License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/LM Sans 10
# Fichero SIL Open Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/Yanone-Kaffeesatz
# Fichero Bitstream Vera License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/Verily-Serif-Mono
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/bitter
# Fichero Bitter OFL SIL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/bitter
# Fichero Cambo SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/cambo
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/kreon
# Fichero METADATA_comments.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/kreon/src
# Fichero GUST e-foundry License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Claire/TeX-Gyre-Adventor
# Fichero SIL Open Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/arvo
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/Galatia-SIL
# Fichero OFL-FAQ.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/Galatia-SIL
# Fichero Galatia SIL OFL License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/Galatia-SIL
# Fichero Bernd Montag License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/Sansation
# Fichero Neuton SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/neuton
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/podkova
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/podkova
# Fichero Podkova SIL OFL Font License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/podkova
# Fichero License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/weblysleek_ui
# Fichero SIL OFL Font License Armata.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/Armata
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/Armata
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/Source_Code_Pro
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Manuel/Cousine
# Fichero RNIB License Agreement.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laura W/Tiresias-Infofont
# Fichero LICENSE.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laura W/Luxi Serif
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laura W/Prata
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laura W/Inika
# Fichero Rokkitt SIL OFL Font License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laura W/rokkitt
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laura W/Domine
# Fichero Oxygen SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laura W/oxygen
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laura W/Archivo_Narrow
# Fichero License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laura W/baskervald
# Fichero Philipp Poll License - LinuxLibertine.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laura W/Linux-Libertine
# Fichero Amaranth SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laura W/amaranth
# Fichero SIL OFL Font License Tienne.txt en /home/jileon/font-specimens/fonts/fonts-perso/Laura W/tienne
# Fichero Ralph Oliver du Carrois License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/Colaborate
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/Consola-Mono
# Fichero SIL - Open Font License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/Consola-Mono
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/petrona
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/petrona
# Fichero PetronaDescription.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/petrona
# Fichero INFO.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/monda
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/monda
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/monda
# Fichero SIL OFL Font License Unna.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/unna
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/novaflat
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/novaflat
# Fichero METADATA_comments.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/novaflat/src
# Fichero LICENSE.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/LM Mono Prop Light 10
# Fichero GUST e-foundry License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/LM Mono Prop Light 10
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/wireone
# Fichero METADATA_comments.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/wireone/src
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/Oxygen_Mono
# Fichero Radley SIL OFL Font License 1.1.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/radley
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/Exo
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/nunito
# Fichero METADATA_comments.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/nunito/src
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/oswald
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/oswald
# Fichero licence.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/U001
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/novamono
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/novamono
# Fichero METADATA_comments.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/novamono/src
# Fichero License.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/Berenis-ADF
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/fonts-perso/Lucas/Scada
# Fichero Brawler SIL OFL Font License.txt en /home/jileon/font-specimens/fonts/brawler
# Fichero COPYING.txt en /home/jileon/font-specimens/fonts/encore_des_fontes_manu/Caliban
# Fichero LICENSE.txt en /home/jileon/font-specimens/fonts/encore_des_fontes_manu/Caliban
# Fichero README.txt en /home/jileon/font-specimens/fonts/encore_des_fontes_manu/Caliban
# Fichero licence.txt en /home/jileon/font-specimens/fonts/encore_des_fontes_manu/letter-gothic
# Fichero licence.txt en /home/jileon/font-specimens/fonts/encore_des_fontes_manu/A030
# Fichero licence.txt en /home/jileon/font-specimens/fonts/encore_des_fontes_manu/Garamond-No8
# Fichero COPYING.txt en /home/jileon/font-specimens/fonts/encore_des_fontes_manu/CaslonRoman
# Fichero LICENSE.txt en /home/jileon/font-specimens/fonts/encore_des_fontes_manu/CaslonRoman
# Fichero README.txt en /home/jileon/font-specimens/fonts/encore_des_fontes_manu/CaslonRoman
# Fichero licence.txt en /home/jileon/font-specimens/fonts/encore_des_fontes_manu/A028
# Fichero FONTLOG.txt en /home/jileon/font-specimens/fonts/encore_des_fontes_manu/PropCourierSans
# Fichero OFL.txt en /home/jileon/font-specimens/fonts/kreon
# Fichero METADATA_comments.txt en /home/jileon/font-specimens/fonts/kreon/src
# Fichero char-selection.txt en /home/jileon/font-specimens/txt-source
# Fichero Instructions.txt en /home/jileon/font-specimens/index
# Fichero El viaje de los siete demonios - Mujica Lainez_ Manuel.txt en /home/jileon/Biblioteca de calibre/Mujica Lainez_ Manuel/El viaje de los siete demonios (44)
# Fichero My Clippings - Desconocido.txt en /home/jileon/Biblioteca de calibre/Desconocido/My Clippings (724)

# %%
for t in os.walk("archivo"):
    dirpath, _, files = t
    for filename in files:
        full_path = os.path.join(dirpath, filename)
        print(full_path)
# Out:
# archivo/2018/nov/fac01.txt
# archivo/2019/feb/fac22.txt
# archivo/2020/ene/fac23.txt

# %%
# !touch a/b/c/hola.txt
# !ls a/b/c
# Out:
# d  hola.txt

# %% [markdown]
# **Ejercicio**: Hacer un script que calcule cuanto ocupan todos los ficheros en un
# determinado directorio, incluyendo sus subdirectorios, si los hubiera. Listar
# los nombres absolutos, es decir, incluyendo la ruta desde la raíz, y al final
# imprimir el espacio total que ocupan en disco.

# %%
acc = 0
for t in os.walk("archivo"):
    dirpath, _, files = t
    for filename in files:
        full_path = os.path.join(dirpath, filename)
        size = os.path.getsize(full_path)
        print(full_path, "ocupa", size, "bytes")
        acc = acc + size
print(f"En total, {acc} bytes")
# Out:
# archivo/2018/nov/fac01.txt ocupa 0 bytes
# archivo/2019/feb/fac22.txt ocupa 12 bytes
# archivo/2020/ene/fac23.txt ocupa 0 bytes
# En total, 12 bytes

# %%
# !echo "hola, mundo" > ./archivo/2019/feb/fac22.txt
