# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([1, 2, 3, 3, 2, 4.5, 4, 5, 6,])

# %%
plt.plot(a)

# %%
plt.plot(a, marker='+', color='r')
plt.title('hola');

# %%
plt.barh?

# %%
y = [3, 10, 7, 5, 3, 4.5, 6, 8.1]
x = [65+i for i in range(len(y))]
width = 0.9

plt.bar(x, y, width, color="#336699")
plt.xticks(x, [chr(_) for _ in x]);

# %% [markdown]
# <https://pythonspot.com/en/matplotlib-bar-chart/>

# %% [markdown]
# ## Preguntas
#
# - Como configurar Jupyter para que las nuevas celdas sean de tipo Mardown, por ejemlpo, en vez de `code`:
#
# <https://stackoverflow.com/questions/40382454/jupyter-notebook-new-cell-type-default>

# %% [markdown]
# - Poner parte de un texto invisible.
#
# <p style="display: none;">Este texto no deberia mostrarse en la celda renderizada</p>
#
# ¿Funciona?

# %%
import pygments

# %%
pygments?
